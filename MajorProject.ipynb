# %%
import pandas as pd

# %%
ttnc=pd.read_csv("/content/CAR DETAILS FROM CAR DEKHO.csv")
ttnc
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
ttnc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
ttnc.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
ttnc
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
ttnc.head(12)
# Out:
#                          name  year  selling_price  km_driven    fuel  \
# 0               Maruti 800 AC  2007          60000      70000  Petrol
# 1    Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2        Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3      Datsun RediGO T Option  2017         250000      46000  Petrol
# 4       Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5        Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6   Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7    Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8    Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9    Maruti Celerio Green VXI  2017         365000      78000     CNG
# 10    Chevrolet Sail 1.2 Base  2015         260000      35000  Petrol
# 11   Tata Indigo Grand Petrol  2014         250000     100000  Petrol
#
#    seller_type transmission         owner
# ...

# %%
ttnc.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
ttnc.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
ttnc.tail(12)
# Out:
#                                               name  year  selling_price  \
# 4328                  Mahindra Verito 1.5 D6 BSIII  2012         200000
# 4329                  Tata Manza Aura Safire BS IV  2010         160000
# 4330                Tata Indica Vista Aqua 1.4 TDI  2010         150000
# 4331          Ford EcoSport 1.5 TDCi Titanium BSIV  2015         530000
# 4332                  Mahindra Scorpio S2 7 Seater  2015         750000
# 4333                               Maruti Ritz VDi  2012         225000
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012         600000
# 4335           Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999
# 4336                    Hyundai i20 Magna 1.4 CRDi  2014         409999
# 4337                           Maruti 800 AC BSIII  2009         110000
# 4338              Hyundai Creta 1.6 CRDi SX Option  2016         865000
# 4339                              Renault KWID RXT  2016         225000
#
# ...

# %%
ttnc.sample()
# Out:
#                           name  year  selling_price  km_driven    fuel  \
# 2490  Hyundai EON 1.0 Era Plus  2019         400000       5000  Petrol
#
#      seller_type transmission        owner
# 2490  Individual       Manual  First Owner

# %%
ttnc.sample(12)
# Out:
#                                             name  year  selling_price  \
# 211            Skoda Rapid 1.5 TDI Ambition BSIV  2018         940000
# 1332  Mahindra Bolero Power Plus Plus AC BSIV PS  2015         450000
# 2761       Ford Aspire Titanium Plus Diesel BSIV  2019         675000
# 2961              Mahindra Scorpio VLS 2.2 mHawk  2008         300000
# 3451                      Maruti SX4 ZXI MT BSIV  2011         150000
# 1712                      Maruti Baleno Zeta 1.2  2017         641000
# 2439                      Maruti Swift Dzire LXi  2011         150000
# 1906                      Maruti Swift Dzire VDI  2015         455000
# 3529           Ford Ecosport 1.5 DV5 MT Titanium  2015         470000
# 2017              Volkswagen Polo SR Petrol 1.2L  2013         380000
# 1683                      Maruti Swift Dzire LDI  2015         430000
# 2008              Ford Freestyle Titanium Diesel  2019         750000
#
# ...

# %%
ttnc.iloc[[2,3,4,5], :]
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 2    Hyundai Verna 1.6 SX  2012         600000     100000  Diesel  Individual
# 3  Datsun RediGO T Option  2017         250000      46000  Petrol  Individual
# 4   Honda Amaze VX i-DTEC  2014         450000     141000  Diesel  Individual
# 5    Maruti Alto LX BSIII  2007         140000     125000  Petrol  Individual
#
#   transmission         owner
# 2       Manual   First Owner
# 3       Manual   First Owner
# 4       Manual  Second Owner
# 5       Manual   First Owner

# %%
ttnc.iloc[3:12,3:7]
# Out:
#     km_driven    fuel seller_type transmission
# 3       46000  Petrol  Individual       Manual
# 4      141000  Diesel  Individual       Manual
# 5      125000  Petrol  Individual       Manual
# 6       25000  Petrol  Individual       Manual
# 7       60000  Petrol  Individual       Manual
# 8       25000  Petrol  Individual       Manual
# 9       78000     CNG  Individual       Manual
# 10      35000  Petrol  Individual       Manual
# 11     100000  Petrol  Individual       Manual

# %%
abc=pd.DataFrame(ttnc)
abc
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
type(abc)
# Out:
# pandas.core.frame.DataFrame

# %%
#import numpy as np
#from numpy import math
#from sklearn.processing import MinMaxScaler
#from sklearn.linear_model import LinearRegression
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import mean_squared_log_error
#from sklearn.metrics import r2_score*/

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(ttnc['year'],ttnc['selling_price'],alpha=0.5)
plt.title('SALES OF CARS IN DIFFERENT YEARS')
plt.xlabel('year')
plt.ylabel('selling_price')
plt.show()

# %%
ax=ttnc.groupby(['km_driven']) ['selling_price'].mean().plot.bar(
    figsize=(10,5),
    fontsize=14
)
ax.set_title("Average of km_driven and selling_price")
ax.set_xlabel("km_driven",fontsize=15)
ax.set_ylabel("selling_price",fontsize=15)
# Out:
# Text(0, 0.5, 'selling_price')
